# %%
from __future__ import print_function
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.5885, 0.4784, 0.1593],
#         [0.8815, 0.2250, 0.9171],
#         [0.1230, 0.1460, 0.7746],
#         [0.1946, 0.2840, 0.8002],
#         [0.1218, 0.9307, 0.4527]])
