# %% [markdown]
# # Running Basic Python Codes with Google Colab

# %% [markdown]
# Running basic Data Types code from Python Numpy tutorial

# %%
x = 3
x
# Out:
# 3

# %%
print(type(x)) # Prints "<class 'int'>"
# Out:
# <class 'int'>

# %%
print(x) # Prints "3"
# Out:
# 3

# %%
print(x + 1) # Addition; prints "4"
# Out:
# 4

# %% [markdown]
# # Running or Importing .py Files with Google Colab

# %% [markdown]
# Run this code to install the necessary libraries and perform authorization

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/Deep Learning Turkey Example/"
# Out:
# deep_learning_turkey.ipynb  mnist_cnn.py  Titanic.csv

# %% [markdown]
# ## Install Keras

# %%
# !pip install -q keras

# %% [markdown]
# Run the following code to train a simple convnet on the 'mnist_cnn.py' dataset

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/Deep Learning Turkey Example/mnist_cnn.py"
# Out:
# Using TensorFlow backend.
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# WARNING: Logging before flag parsing goes to stderr.
# W0830 17:27:49.669061 140494446204800 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0830 17:27:49.713189 140494446204800 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0830 17:27:49.718837 140494446204800 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# Each 'Epoch' above lasts roughly 8 to 9 seconds in the results output.

# %% [markdown]
# ## Download Titanic Dataset (.csv) Using the !wget Command

# %% [markdown]
# In this exercise, try and import the first 5 rows of data.

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -p "/content/drive/My Drive/Colab Notebooks/Deep Learning Turkey Example"
# Out:
# --2019-08-31 18:16:14--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv’
#
# raw.githubuserconte 100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2019-08-31 18:16:14 (213 MB/s) - ‘raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv’ saved [1170/1170]
#
# /content/drive/My Drive/Colab Notebooks/Deep Learning Turkey Example: Scheme missing.
# FINISHED --2019-08-31 18:16:14--
# Total wall clock time: 0.1s
# Downloaded: 1 files, 1.1K in 0s (213 MB/s)

# %% [markdown]
# If this doesn't work then try the following code having uploaded the 'Titanic.csv' file to the correct Google Drive folder, in this case the 'Deep Learning Turkey Example' folder.

# %%
import pandas as pd
titanic = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Deep Learning Turkey Example/Titanic.csv")
titanic.head(5)
# Out:
#    Column1 Class     Sex    Age Survived  Freq
# 0        1   1st    Male  Child       No     0
# 1        2   2nd    Male  Child       No     0
# 2        3   3rd    Male  Child       No    35
# 3        4  Crew    Male  Child       No     0
# 4        5   1st  Female  Child       No     0

# %% [markdown]
# ## Cloning GitHub Repo to Google Colab

# %% [markdown]
# Find the GitHub repo in: https://github.com/wxs/keras-mnist-tutorial.
# Click on the clone or download repository button on the right.
# Next, type the following command to retrieve the tutorial repo in a code cell below:

# %%
# !git clone https://github.com/wxs/keras-mnist-tutorial.git

# %% [markdown]
# Go to Google Drive/Colab Notebooks/Deep Learning Turkey Example and right-click on 'MNIST in Keras.ipynb' > Open With > Colaboratory

# %% [markdown]
# ## Further Tips

# %% [markdown]
# ### 1. Installing libraries
# Keras

# %%
# !pip install -q keras
import mxnet as mx
# Out:
# Using TensorFlow backend.

# %% [markdown]
# PyTorch

# %%
# !pip3 install torch torchvision

# %% [markdown]
# MxNet

# %%
# !apt install libnvrtc8.0
# !pip install mxnet-cu80
import mxnet as mx
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libnvrtc8.0
# E: Couldn't find any package by glob 'libnvrtc8.0'
# E: Couldn't find any package by regex 'libnvrtc8.0'
# ...
#      |████████████████████████████████| 372.1MB 87kB/s
# ...
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-a6ca1f8f042b> in <module>()
#       1 get_ipython().system('apt install libnvrtc8.0')
#       2 get_ipython().system('pip install mxnet-cu80')
# ----> 3 import mxnet as mx
#
# /usr/local/lib/python3.6/dist-packages/mxnet/__init__.py in <module>()
#      22 from __future__ import absolute_import
#      23
# ---> 24 from .context import Context, current_context, cpu, gpu, cpu_pinned
# ...

# %%
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-
python
import cv2
